# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib.pyplot in line
# Out:
# UsageError: Line magic function `%matplotlib.pyplot` not found.

# %%
up_acc  = pd.read_csv('Sensory/up/Accelerometer.csv', sep=",", decimal=".", header=0)
up_acc_lin =  pd.read_csv('Sensory/up/AccelerometerLinear.csv', sep=",", decimal=".", header=0)
up_gyro = pd.read_csv('Sensory/up/Gyroscope.csv', sep=",", decimal=".", header=0)
walking = pd.read_csv('Sensory/walking/Gyroscope.csv', sep=",", decimal=".", header=0)

# %%
# plt.figure() #figsize=(20, 10)
# up_acc.plot(x='Timestamp', y='Y')
# up_acc_lin.plot(x='Timestamp', y='Y')
# up_gyro.plot(x='Timestamp', y='Y')
# up_acc.plot(x='Timestamp', y='X')
# up_acc.plot(x='Timestamp', y='Z')
# up_acc_lin.plot(x='Timestamp', y='X')
# up_acc_lin.plot(x='Timestamp', y='Z')
# plt.plot(up_acc.Timestamp, up_acc.Y, up_acc_lin.Timestamp, up_acc_lin.Y)
# plt.show()

# %%
def plot(data):
    plt.figure(figsize=((100, 50)))
    data.plot(x='Timestamp', y='Y')
    plt.show()
    
# plot(walking)
plt.figure(figsize=(200, 200))
walking.plot(x='Timestamp', y='Y')
plt.show()
